# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ## Splitting participants_price

# %% [markdown]
# There are some columns which have values separated by "|". It is interesting to split these into different rows (one per value) in order to train the model. Here is an example with participants_price, although there are others which have to be also considered.

# %%
import pandas as pd
df = pd.read_csv('interview_analysis_molecule_x_10mg_v1.tsv', sep='\t')

# %%
#Converting the dataset into vertical mode
df['participants'] = df['participants'].str.split('|')
df['participants_price'] = df['participants_price'].str.split('|')

# Create new column with tuples
df['combined'] = df.apply(lambda row: list(zip(row['participants'], row['participants_price'])), axis=1)

# Explode 'combined' column
df = df.explode('combined')

# Create separate columns from 'combined'
df['participants'], df['participants_price'] = zip(*df['combined'])

# Drop 'combined' column
df = df.drop(columns=['combined'])

df['participants'] = df['participants'].str.strip()
df['participants_price'] = df['participants_price'].str.strip()

# %% [markdown]
# ## 1. Independent variable winner_price

# %%
df.head()
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength     participants  \
# 0               0.10000        molecule_x          10mg  participants_16
# 1           63442.21000        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_23
# 3               0.03000        molecule_x          10mg  participants_16
#
#    participants_price  published_date_month           winner winner_price  \
# 0              0.0004            2013-05-01  participants_16       0.0004
# 1               0.007            2013-04-01  participants_16       0.0070
# 2               0.014            2013-06-01  participants_16       0.0140
# 2             0.07071            2013-06-01  participants_16       0.0140
# 3               0.025            2013-05-01  participants_16       0.0250
#
#       second_place second_place_price
# 0              NaN                NaN
# 1              NaN                NaN
# 2  participants_23            0.07071
# 2  participants_23            0.07071
# 3              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# As I dont have much time, I will just clean it in a not "nice" way. However, for theses cases I like to use pydantic as it simplifies data validation.

# %% [markdown]
# ### 1.1 Errors (automatic discard)

# %% [markdown]
# #### 1.1.1 winner_price should be float

# %%
mask = df['winner_price'].apply(lambda x: isinstance(x, float))

# %%
df1 = df[mask]

# %%
df_incorrectos = df[~mask]
print(df_incorrectos)
# Out:
# Empty DataFrame
# Columns: [contract_id, published_date, start_date, duration_extension, outcome, second_place_outcome, buyer, region, atc, duration, contract_type, sku, end_date_extension, participants_no, quantity_annual, quantity_total, maximum_price_allowed, active_ingredient, pack_strength, participants, participants_price, published_date_month, winner, winner_price, second_place, second_place_price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df1.head()
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength     participants  \
# 0               0.10000        molecule_x          10mg  participants_16
# 1           63442.21000        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_23
# 3               0.03000        molecule_x          10mg  participants_16
#
#    participants_price  published_date_month           winner winner_price  \
# 0              0.0004            2013-05-01  participants_16       0.0004
# 1               0.007            2013-04-01  participants_16       0.0070
# 2               0.014            2013-06-01  participants_16       0.0140
# 2             0.07071            2013-06-01  participants_16       0.0140
# 3               0.025            2013-05-01  participants_16       0.0250
#
#       second_place second_place_price
# 0              NaN                NaN
# 1              NaN                NaN
# 2  participants_23            0.07071
# 2  participants_23            0.07071
# 3              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# #### 1.1.2. Check NaN/Not null

# %%
import numpy as np

# %%
mask = df1['winner_price'].apply(lambda x: x is not np.nan)

# %%
df2 = df1[mask]

# %%
#Always appending the new incorrect data into a dataframe with all the wrong rows
df_incorrectos=pd.concat([df_incorrectos, df1[~mask]])

# %%
print(df_incorrectos)
# Out:
# Empty DataFrame
# Columns: [contract_id, published_date, start_date, duration_extension, outcome, second_place_outcome, buyer, region, atc, duration, contract_type, sku, end_date_extension, participants_no, quantity_annual, quantity_total, maximum_price_allowed, active_ingredient, pack_strength, participants, participants_price, published_date_month, winner, winner_price, second_place, second_place_price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df2.head()
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength     participants  \
# 0               0.10000        molecule_x          10mg  participants_16
# 1           63442.21000        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_23
# 3               0.03000        molecule_x          10mg  participants_16
#
#    participants_price  published_date_month           winner winner_price  \
# 0              0.0004            2013-05-01  participants_16       0.0004
# 1               0.007            2013-04-01  participants_16       0.0070
# 2               0.014            2013-06-01  participants_16       0.0140
# 2             0.07071            2013-06-01  participants_16       0.0140
# 3               0.025            2013-05-01  participants_16       0.0250
#
#       second_place second_place_price
# 0              NaN                NaN
# 1              NaN                NaN
# 2  participants_23            0.07071
# 2  participants_23            0.07071
# 3              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# #### 1.1.3 Check certain range (>0 and < 1 i.e)

# %%
mask = df2['winner_price'].apply(lambda x: 0 <= x <= 1)

# %%
df3 = df2[mask]

# %%
df_incorrectos=pd.concat([df_incorrectos, df2[~mask]])
print(df_incorrectos)
# Out:
# Empty DataFrame
# Columns: [contract_id, published_date, start_date, duration_extension, outcome, second_place_outcome, buyer, region, atc, duration, contract_type, sku, end_date_extension, participants_no, quantity_annual, quantity_total, maximum_price_allowed, active_ingredient, pack_strength, participants, participants_price, published_date_month, winner, winner_price, second_place, second_place_price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df3.head()
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength     participants  \
# 0               0.10000        molecule_x          10mg  participants_16
# 1           63442.21000        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_23
# 3               0.03000        molecule_x          10mg  participants_16
#
#    participants_price  published_date_month           winner winner_price  \
# 0              0.0004            2013-05-01  participants_16       0.0004
# 1               0.007            2013-04-01  participants_16       0.0070
# 2               0.014            2013-06-01  participants_16       0.0140
# 2             0.07071            2013-06-01  participants_16       0.0140
# 3               0.025            2013-05-01  participants_16       0.0250
#
#       second_place second_place_price
# 0              NaN                NaN
# 1              NaN                NaN
# 2  participants_23            0.07071
# 2  participants_23            0.07071
# 3              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2. Relationship winner_price vs. other variable

# %% [markdown]
# ### Winner_price should be <= than participants_price

# %%
mask = df3.apply(lambda row: float(row['winner_price']) <= float(row['participants_price']), axis=1)

# %%
df4 = df3[mask]

# %%
df_incorrectos=pd.concat([df_incorrectos, df3[~mask]])
print(df_incorrectos)
# Out:
# Empty DataFrame
# Columns: [contract_id, published_date, start_date, duration_extension, outcome, second_place_outcome, buyer, region, atc, duration, contract_type, sku, end_date_extension, participants_no, quantity_annual, quantity_total, maximum_price_allowed, active_ingredient, pack_strength, participants, participants_price, published_date_month, winner, winner_price, second_place, second_place_price]
# Index: []
#
# [0 rows x 26 columns]

# %%
df4.head()
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength     participants  \
# 0               0.10000        molecule_x          10mg  participants_16
# 1           63442.21000        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_16
# 2               0.11635        molecule_x          10mg  participants_23
# 3               0.03000        molecule_x          10mg  participants_16
#
#    participants_price  published_date_month           winner winner_price  \
# 0              0.0004            2013-05-01  participants_16       0.0004
# 1               0.007            2013-04-01  participants_16       0.0070
# 2               0.014            2013-06-01  participants_16       0.0140
# 2             0.07071            2013-06-01  participants_16       0.0140
# 3               0.025            2013-05-01  participants_16       0.0250
#
#       second_place second_place_price
# 0              NaN                NaN
# 1              NaN                NaN
# 2  participants_23            0.07071
# 2  participants_23            0.07071
# 3              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 2.2 winner_price <= maximum price allowed

# %%
mask = df4.apply(lambda row: row['winner_price'] <= row['maximum_price_allowed'], axis=1)

# %%
df5 = df4[mask]

# %%
df_incorrectos=pd.concat([df_incorrectos, df4[~mask]])
print(df_incorrectos)
# Out:
# Empty DataFrame
# Columns: [contract_id, published_date, start_date, duration_extension, outcome, second_place_outcome, buyer, region, atc, duration, contract_type, sku, end_date_extension, participants_no, quantity_annual, quantity_total, maximum_price_allowed, active_ingredient, pack_strength, participants, participants_price, published_date_month, winner, winner_price, second_place, second_place_price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## 3. Check other variables on their own or related to other

# %% [markdown]
# ### Maximum allowed price in range 0<price<1

# %%
mask = df5['maximum_price_allowed'].apply(lambda x: 0 <= x <= 1)

# %%
df6 = df5[mask]

# %%
df_incorrectos=pd.concat([df_incorrectos, df5[~mask]])

# %%
print(df_incorrectos)
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 1             2     2013-04-29  2013-06-21                   0     won
# 10           11     2014-08-05  2014-10-30                   0     won
# 10           11     2014-08-05  2014-10-30                   0     won
# 10           11     2014-08-05  2014-10-30                   0     won
# 13           14     2017-10-20  2017-09-20                   3     won
# 23           24     2020-10-11  2020-11-25                   0     won
# 23           24     2020-10-11  2020-11-25                   0     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 1                   NaN   buyer_2   region_2  C07AB07        48  ...
# 10                 lost   buyer_2   region_2  C07AB07        36  ...
# 10                 lost   buyer_2   region_2  C07AB07        36  ...
# 10                 lost   buyer_2   region_2  C07AB07        36  ...
# 13                  NaN  buyer_12  region_12  C07AB07        48  ...
# 23                 lost   buyer_2   region_2  C07AB07        49  ...
# 23                 lost   buyer_2   region_2  C07AB07        49  ...
#
#    maximum_price_allowed active_ingredient pack_strength     participants  \
# 1              63442.210        molecule_x          10mg  participants_16
# 10            664493.870        molecule_x          10mg   participants_6
# 10            664493.870        molecule_x          10mg  participants_16
# 10            664493.870        molecule_x          10mg  participants_23
# 13              6647.872        molecule_x          10mg  participants_16
# 23            963542.280        molecule_x          10mg  participants_19
# 23            963542.280        molecule_x          10mg  participants_23
#
#     participants_price  published_date_month           winner winner_price  \
# 1                0.007            2013-04-01  participants_16       0.0070
# 10               0.034            2014-08-01   participants_6       0.0340
# 10             0.04305            2014-08-01   participants_6       0.0340
# 10             0.04214            2014-08-01   participants_6       0.0340
# 13                0.02            2017-10-01  participants_16       0.0200
# 23              0.0205            2020-10-01  participants_19       0.0205
# 23             0.03929            2020-10-01  participants_19       0.0205
#
#        second_place second_place_price
# 1               NaN                NaN
# 10  participants_23            0.04214
# 10  participants_23            0.04214
# 10  participants_23            0.04214
# 13              NaN                NaN
# 23  participants_23            0.03929
# 23  participants_23            0.03929
#
# [7 rows x 26 columns]

# %%
print(df6)
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 0             1     2013-05-16  2013-05-24                  10     won
# 2             3     2013-06-09  2014-08-14                   6     won
# 2             3     2013-06-09  2014-08-14                   6     won
# 3             4     2013-05-04  2013-05-17                  19     won
# 4             5     2013-12-18  2013-12-17                   6     won
# 5             6     2013-12-06  2014-02-21                  14     won
# 6             7     2014-02-24  2014-01-01                   3     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 8             9     2014-03-18  2014-05-30                   6     won
# 9            10     2014-09-07  2014-08-31                   7     won
# 11           12     2015-02-17  2015-01-01                   3     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 14           15     2017-12-01  2018-01-22                  12     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 20           21     2020-03-21  2020-06-20                  12     won
# 21           22     2020-06-10  2020-04-29                   6     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 24           25     2021-06-09  2021-05-20                   0     won
# 25           26     2021-07-09  2021-07-05                   6     won
# 26           27     2022-03-19  2022-03-31                   6     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 28           29     2022-07-01  2022-06-17                  24    lost
# 28           29     2022-07-01  2022-06-17                  24    lost
# 29           30     2023-07-09  2023-08-01                   0     won
# 29           30     2023-07-09  2023-08-01                   0     won
# 29           30     2023-07-09  2023-08-01                   0     won
# 30           31     2023-10-24  2023-09-26                   6     won
# 30           31     2023-10-24  2023-09-26                   6     won
# 30           31     2023-10-24  2023-09-26                   6     won
# 30           31     2023-10-24  2023-09-26                   6     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 0                   NaN   buyer_1   region_1  C07AB07        39  ...
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 3                   NaN   buyer_4   region_4  C07AB07        36  ...
# 4                   NaN   buyer_5   region_5  C07AB07        36  ...
# 5                   NaN   buyer_6   region_6  C07AB07        48  ...
# 6                   NaN   buyer_7   region_7  C07AB07        12  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 8                   NaN   buyer_9   region_9  C07AB07        24  ...
# 9                   NaN  buyer_10  region_10  C07AB07        36  ...
# 11                  NaN   buyer_7   region_7  C07AB07        12  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 14                  NaN  buyer_13  region_13  C07AB07        36  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 20                  NaN  buyer_15   region_9  C07AB07        36  ...
# 21                  NaN  buyer_16   region_5  C07AB07        24  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 24                  NaN  buyer_17  region_14  C07AB07        48  ...
# 25                  NaN  buyer_12  region_12  C07AB07        48  ...
# 26                  NaN  buyer_18  region_15  C07AB07        24  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
#
#    maximum_price_allowed active_ingredient pack_strength     participants  \
# 0                0.10000        molecule_x          10mg  participants_16
# 2                0.11635        molecule_x          10mg  participants_16
# 2                0.11635        molecule_x          10mg  participants_23
# 3                0.03000        molecule_x          10mg  participants_16
# 4                0.00010        molecule_x          10mg  participants_16
# 5                0.02550        molecule_x          10mg  participants_16
# 6                0.00005        molecule_x          10mg  participants_16
# 7                0.08000        molecule_x          10mg  participants_16
# 7                0.08000        molecule_x          10mg   participants_5
# 7                0.08000        molecule_x          10mg   participants_6
# 7                0.08000        molecule_x          10mg  participants_23
# 8                0.00010        molecule_x          10mg  participants_16
# 9                0.00010        molecule_x          10mg  participants_16
# 11               0.00005        molecule_x          10mg  participants_16
# 12               0.07971        molecule_x          10mg   participants_6
# 12               0.07971        molecule_x          10mg  participants_16
# 12               0.07971        molecule_x          10mg  participants_23
# 12               0.07971        molecule_x          10mg  participants_24
# 14               0.10900        molecule_x          10mg  participants_16
# 15               0.02500        molecule_x          10mg  participants_16
# 15               0.02500        molecule_x          10mg   participants_4
# 16               0.02000        molecule_x          10mg  participants_16
# 16               0.02000        molecule_x          10mg   participants_7
# 17               0.02200        molecule_x          10mg  participants_16
# 17               0.02200        molecule_x          10mg  participants_19
# 18               0.07971        molecule_x          10mg  participants_19
# 18               0.07971        molecule_x          10mg  participants_16
# 18               0.07971        molecule_x          10mg  participants_23
# 19               0.07971        molecule_x          10mg  participants_19
# 19               0.07971        molecule_x          10mg  participants_16
# 19               0.07971        molecule_x          10mg  participants_23
# 20               0.02200        molecule_x          10mg  participants_19
# 21               0.02000        molecule_x          10mg  participants_19
# 22               0.04000        molecule_x          10mg  participants_19
# 22               0.04000        molecule_x          10mg   participants_8
# 22               0.04000        molecule_x          10mg  participants_23
# 24               0.01250        molecule_x          10mg  participants_19
# 25               0.02001        molecule_x          10mg  participants_19
# 26               0.01250        molecule_x          10mg  participants_19
# 27               0.01600        molecule_x          10mg  participants_19
# 27               0.01600        molecule_x          10mg  participants_23
# 28               0.03929        molecule_x          10mg  participants_19
# 28               0.03929        molecule_x          10mg  participants_23
# 29               0.03000        molecule_x          10mg  participants_19
# 29               0.03000        molecule_x          10mg  participants_16
# 29               0.03000        molecule_x          10mg  participants_23
# 30               0.09322        molecule_x          10mg  participants_19
# 30               0.09322        molecule_x          10mg   participants_7
# 30               0.09322        molecule_x          10mg  participants_16
# 30               0.09322        molecule_x          10mg  participants_23
#
#     participants_price  published_date_month           winner winner_price  \
# 0               0.0004            2013-05-01  participants_16      0.00040
# 2                0.014            2013-06-01  participants_16      0.01400
# 2              0.07071            2013-06-01  participants_16      0.01400
# 3                0.025            2013-05-01  participants_16      0.02500
# 4                1e-05            2013-12-01  participants_16      0.00001
# 5                0.019            2013-12-01  participants_16      0.01900
# 6                1e-05            2014-02-01  participants_16      0.00001
# 7                 0.03            2014-03-01  participants_16      0.03000
# 7                 0.08            2014-03-01  participants_16      0.03000
# 7                0.034            2014-03-01  participants_16      0.03000
# 7              0.04066            2014-03-01  participants_16      0.03000
# 8                1e-05            2014-03-01  participants_16      0.00001
# 9               0.0001            2014-09-01  participants_16      0.00010
# 11               5e-05            2015-02-01  participants_16      0.00005
# 12             0.01699            2016-04-01   participants_6      0.01699
# 12                0.07            2016-04-01   participants_6      0.01699
# 12             0.06802            2016-04-01   participants_6      0.01699
# 12               0.075            2016-04-01   participants_6      0.01699
# 14                0.05            2017-12-01  participants_16      0.05000
# 15               0.017            2017-12-01  participants_16      0.01700
# 15              0.0242            2017-12-01  participants_16      0.01700
# 16                0.02            2018-05-01  participants_16      0.02000
# 16  0.9993156095718888            2018-05-01  participants_16      0.02000
# 17                0.02            2019-05-01  participants_16      0.02000
# 17  0.8665684755636098            2019-05-01  participants_16      0.02000
# 18             0.01786            2020-01-01  participants_19      0.01786
# 18                0.07            2020-01-01  participants_19      0.01786
# 18             0.06511            2020-01-01  participants_19      0.01786
# 19             0.01786            2019-12-01  participants_19      0.01786
# 19                0.07            2019-12-01  participants_19      0.01786
# 19             0.06511            2019-12-01  participants_19      0.01786
# 20             0.01607            2020-03-01  participants_19      0.01607
# 21              0.0125            2020-06-01  participants_19      0.01250
# 22               0.035            2020-06-01  participants_19      0.03500
# 22               0.038            2020-06-01  participants_19      0.03500
# 22             0.03929            2020-06-01  participants_19      0.03500
# 24              0.0123            2021-06-01  participants_19      0.01230
# 25               0.018            2021-07-01  participants_19      0.01800
# 26              0.0122            2022-03-01  participants_19      0.01220
# 27               0.015            2022-07-01  participants_19      0.01500
# 27             0.01571            2022-07-01  participants_19      0.01500
# 28               0.034            2022-07-01  participants_23      0.02393
# 28             0.02393            2022-07-01  participants_23      0.02393
# 29               0.015            2023-07-01  participants_19      0.01500
# 29               0.025            2023-07-01  participants_19      0.01500
# 29             0.02679            2023-07-01  participants_19      0.01500
# 30              0.0155            2023-10-01  participants_19      0.01550
# 30             0.06256            2023-10-01  participants_19      0.01550
# 30                0.08            2023-10-01  participants_19      0.01550
# 30             0.09286            2023-10-01  participants_19      0.01550
#
#        second_place second_place_price
# 0               NaN                NaN
# 2   participants_23           0.070710
# 2   participants_23           0.070710
# 3               NaN                NaN
# 4               NaN                NaN
# 5               NaN                NaN
# 6               NaN                NaN
# 7    participants_6           0.034000
# 7    participants_6           0.034000
# 7    participants_6           0.034000
# 7    participants_6           0.034000
# 8               NaN                NaN
# 9               NaN                NaN
# 11              NaN                NaN
# 12  participants_23           0.068020
# 12  participants_23           0.068020
# 12  participants_23           0.068020
# 12  participants_23           0.068020
# 14              NaN                NaN
# 15   participants_4           0.024200
# 15   participants_4           0.024200
# 16   participants_7           0.999316
# 16   participants_7           0.999316
# 17  participants_19           0.866568
# 17  participants_19           0.866568
# 18  participants_23           0.065110
# 18  participants_23           0.065110
# 18  participants_23           0.065110
# 19  participants_23           0.065110
# 19  participants_23           0.065110
# 19  participants_23           0.065110
# 20              NaN                NaN
# 21              NaN                NaN
# 22   participants_8           0.038000
# 22   participants_8           0.038000
# 22   participants_8           0.038000
# 24              NaN                NaN
# 25              NaN                NaN
# 26              NaN                NaN
# 27  participants_23           0.015710
# 27  participants_23           0.015710
# 28  participants_19           0.034000
# 28  participants_19           0.034000
# 29  participants_16           0.025000
# 29  participants_16           0.025000
# 29  participants_16           0.025000
# 30   participants_7           0.062560
# 30   participants_7           0.062560
# 30   participants_7           0.062560
# 30   participants_7           0.062560
#
# [50 rows x 26 columns]

# %% [markdown]
# There are many other possible analysis, for example, checking that maximum_price is in a determined range.

# %% [markdown]
# ## Log wrong data into file

# %%
from datetime import datetime

now = datetime.now()

timestamp_str = now.strftime("%Y_%m_%d%H_%M_%S")

df_incorrectos['execution_time'] = timestamp_str

filename = f"error_log_{timestamp_str}.csv"

df_incorrectos.to_csv(filename, mode='a', header=False)

# %% [markdown]
# ## Log clean data into file
#
# I will write the clean data into a csv file as an example, another possibility would be writing into an SQL table.

# %%
filename = f"clean_data_{timestamp_str}.csv"

df6.to_csv(filename, mode='a', header=True)

# %% [markdown]
# ## Questions

# %% [markdown]
# As I am running out of time, I won´t be able to perform further cleansing. However, many other tasks can be carried out, for example: check dates format, check that the number of bids in participants_price = participants_no...

# %% [markdown]
# Furthermore, depending on the models which will be implemented, the data probably has to be adapted and the column participants_price converted into a vertical mode. That means, having one row for each bid in a contract instead of having one row per contract and all the bids in one cell, as that makes it impossible the model training.

# %% [markdown]
# ### What manual tasks would you perform?

# %% [markdown]
# I would automate the whole process but including some data visualization and an error log, in order the give the analysts some insights about how the process is and checking visually with some graphs that the data is correct. It would be interesting to set some KPIs, in order to follow the process and the evolution in time. For example, if there is an NaN rate of 1NaN per 1000 rows and we set it as a KPI, we may see it increase from 1 to 50 and therefore suggests that date is coming with poor quality.

# %% [markdown]
# ###  How would you improve this process long term and how would you build your roadmap?

# %% [markdown]
# As mentioned before, at the beginning it may be ok with just a python script but in the future some logging, data visualization and KPIs display should be developed in order to follow the process when it is deployed into production. To begin with, the data does not seem to be too difficult in order to set an automatic Python script which may run on a daily basis and uploads the clean data into an SQL table. As the data flow increases, it will be interesting to analyze cleansing and processing times and then set a strategy It may be enough with just one server running serverless or we may need multiprocessing and some optimization, but we will only know that as the project scalates.

# %% [markdown]
# ###  Would you change anything if you would need to scale this process from a few SKU's to hundreds and thousands.

# %% [markdown]
# I guess, to begin with, the process can run locally on the analyst's computer and the data can be uploaded to the database. If the running times are way too long, first, the script has to be optimized in order to decrease execution times. However, if running times cannot be handled locally, it will be interesting to run the script/process on a server. Here we have two possibilities: running serverless or on a server. Depending on the company's infrastructure we may choose one or the other. If already some server is deployed and not running on full capacity, we may use it in order to optimize server usage. However, another possibility may be running it serverless (as AWS lambda functions) so that costs are optimized.
